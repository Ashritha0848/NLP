# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashritha0848/NLP/blob/main/2403A52229%2CBatch_9%2CAssignment_9_3%2CNLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gensim
# !pip install matplotlib
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.1.1)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 50.4 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# gensim is used to load and work with pre-trained word embedding models
# It provides Word2Vec, GloVe, FastText implementations
import gensim

# KeyedVectors is specifically used to load pre-trained word embeddings
# without loading the full training model
from gensim.models import KeyedVectors

# numpy is used for numerical operations on vectors
# Word embeddings are stored as numerical arrays
import numpy as np

# sklearn.metrics.pairwise is used to calculate similarity between vectors
# cosine_similarity helps measure semantic similarity between words
from sklearn.metrics.pairwise import cosine_similarity

# matplotlib is used to visualize word embeddings in 2D space
import matplotlib.pyplot as plt

# %%
import gensim.downloader as api
from gensim.models import KeyedVectors

# Load pre-trained Word2Vec model (may take time on first download)
model = api.load("word2vec-google-news-300")

# Print vocabulary size
print("Vocabulary Size:", len(model.key_to_index))

# Display vector for a sample word
word = "king"
vector = model[word]

print("\nWord:", word)
print("Vector length:", len(vector))
print("First 10 values of the vector:\n", vector[:10])
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded
# Vocabulary Size: 3000000
#
# Word: king
# Vector length: 300
# First 10 values of the vector:
#  [ 0.12597656  0.02978516  0.00860596  0.13964844 -0.02563477 -0.03613281
#   0.11181641 -0.19824219  0.05126953  0.36328125]

# %%
import gensim.downloader as api

# Load pre-trained GloVe model (100D)
model = api.load("glove-wiki-gigaword-100")

# Define word pairs
word_pairs = [
    ("lion", "tiger"),
    ("pen", "pencil"),
    ("book", "library"),
    ("chair", "table"),
    ("bread", "butter"),
    ("phone", "charger"),
    ("rain", "cloud"),
    ("train", "station"),
    ("bird", "nest"),
    ("shoe", "sock")
]


print("Word Similarity Scores:\n")

for w1, w2 in word_pairs:
    similarity = model.similarity(w1, w2)
    print(f"{w1} - {w2} : {similarity:.4f}")
# Out:
# Word Similarity Scores:
#
# lion - tiger : 0.5734
# pen - pencil : 0.6101
# book - library : 0.5616
# chair - table : 0.4925
# bread - butter : 0.7280
# phone - charger : 0.2911
# rain - cloud : 0.5149
# train - station : 0.6394
# bird - nest : 0.4683
# shoe - sock : 0.3890

# %%
import gensim.downloader as api

# Load pre-trained GloVe embeddings (100D)
model = api.load("glove-wiki-gigaword-100")

# Choose at least 5 words
chosen_words = ["shoe", "rain", "chair", "bread", "phone"]

for word in chosen_words:
    print(f"\nTop similar words for '{word}':\n")

    similar_words = model.most_similar(word, topn=5)

    for similar_word, score in similar_words:
        print(f"{similar_word} : {score:.4f}")
# Out:
# Top similar words for 'shoe':
#
# shoes : 0.7418
# clothing : 0.6785
# leather : 0.6634
# apparel : 0.6597
# footwear : 0.6482
#
# Top similar words for 'rain':
#
# rains : 0.8024
# snow : 0.7520
# winds : 0.7494
# downpour : 0.7370
# fog : 0.7337
#
# Top similar words for 'chair':
#
# chairs : 0.7821
# head : 0.6700
# sitting : 0.6608
# door : 0.6043
# floor : 0.5983
#
# Top similar words for 'bread':
#
# flour : 0.7655
# baked : 0.7607
# cake : 0.7606
# loaf : 0.7457
# toast : 0.7398
#
# Top similar words for 'phone':
#
# telephone : 0.9113
# cellphone : 0.8122
# phones : 0.8031
# mobile : 0.7307
# mail : 0.7292

# %%
import gensim.downloader as api

# Load pre-trained Word2Vec model
model = api.load("word2vec-google-news-300")

# Analogy 1: lion - tiger + cat
result1 = model.most_similar(
    positive=["lion", "cat"],
    negative=["tiger"],
    topn=5
)

# Analogy 2: pen - pencil + book
result2 = model.most_similar(
    positive=["pen", "book"],
    negative=["pencil"],
    topn=5
)

# Analogy 3: king - man + woman
result3 = model.most_similar(
    positive=["king", "woman"],
    negative=["man"],
    topn=5
)

# Analogy 4: sun - moon + night
result4 = model.most_similar(
    positive=["sun", "night"],
    negative=["moon"],
    topn=5
)

# Analogy 5: train - station + airport
result5 = model.most_similar(
    positive=["train", "airport"],
    negative=["station"],
    topn=5
)

print("\nlion - tiger + cat = ?")
print(result1)

print("\npen - pencil + book = ?")
print(result2)

print("\nking - man + woman = ?")
print(result3)

print("\nsun - moon + night = ?")
print(result4)

print("\ntrain - station + airport = ?")
print(result5)
# Out:
# lion - tiger + cat = ?
# [('cats', 0.5432893633842468), ('dog', 0.5359207987785339), ('pooch', 0.5049790143966675), ('pet', 0.50178462266922), ('kitties', 0.4979073405265808)]
#
# pen - pencil + book = ?
# [('memoir', 0.6192349195480347), ('autobiography', 0.5959314107894897), ('tome', 0.5697607398033142), ('paperback_edition', 0.5441946387290955), ('novel', 0.5421698689460754)]
#
# king - man + woman = ?
# [('queen', 0.7118193507194519), ('monarch', 0.6189674139022827), ('princess', 0.5902431011199951), ('crown_prince', 0.5499460697174072), ('prince', 0.5377321839332581)]
#
# sun - moon + night = ?
# [('afternoon', 0.608284056186676), ('evening', 0.5941490530967712), ('morning', 0.5110701322555542), ('nights', 0.5069339871406555), ('sunshine', 0.46247929334640503)]
#
# train - station + airport = ?
# [('Airport', 0.5614991188049316), ('International_Airport', 0.5404980778694153), ('trains', 0.5336790084838867), ('airports', 0.49909260869026184), ('flights', 0.48710083961486816)]
